# %%
import CoronaModel_Viz
# Out:
# 245it [01:44,  2.35it/s]
# Interface starting at http://127.0.0.1:8521
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-ad963a0b52df> in <module>
# ----> 1 import CoronaModel_Viz
#
# ~\Desktop\Project154\CoronaModel_Viz.py in <module>
#      34                        {"N":100, "width":10, "height":10})
#      35 server.port = 8521 # The default
# ---> 36 server.launch()
#
# ~\Anaconda3\envs\WorkSpace154\lib\site-packages\mesa\visualization\ModularVisualization.py in launch(self, port)
#     322         webbrowser.open(url)
#     323         tornado.autoreload.start()
# --> 324         tornado.ioloop.IOLoop.current().start()
#
# ~\Anaconda3\envs\WorkSpace154\lib\site-packages\tornado\platform\asyncio.py in start(self)
#     147             self._setup_logging()
#     148             asyncio.set_event_loop(self.asyncio_loop)
# ...
